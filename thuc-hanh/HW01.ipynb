# %% [markdown]
# # HW01: Các câu lệnh Linux, Python
#
# (Cập nhật lần cuối 12/10/2025)
#
# Họ tên: 23120172
#
# MSSV: Trần Thị Thủy Tiên

# %% [markdown]
# ---

# %% [markdown]
# ## Cách làm bài và nộp bài

# %% [markdown]
# &#9889; Bạn lưu ý là mình sẽ dùng chương trình hỗ trợ chấm bài nên bạn cần phải tuân thủ chính xác qui định mà mình đặt ra, nếu không rõ thì hỏi, chứ không nên tự tiện làm theo ý của cá nhân.
#
# **Cách làm bài**
#
# Bạn sẽ làm trực tiếp trên file notebook này. Đầu tiên, bạn điền họ tên và MSSV vào phần đầu file ở bên trên. Trong file, bạn làm bài ở những chỗ có ghi là:
# ```python
# # YOUR CODE HERE
# raise NotImplementedError()
# ```
# hoặc đối với những phần code không bắt buộc thì là:
# ```python
# # YOUR CODE HERE (OPTION)
# ```
# hoặc đối với markdown cell thì là:
# ```markdown
# YOUR ANSWER HERE
# ```
# Tất nhiên, khi làm thì bạn xóa dòng `raise NotImplementedError()` đi.
# Đối những phần yêu cầu code thì thường ở ngay phía dưới sẽ có một (hoặc một số) cell chứa các bộ test để giúp bạn biết đã code đúng hay chưa; nếu chạy cell này không có lỗi gì thì có nghĩa là qua được các bộ test. Trong một số trường hợp, các bộ test có thể sẽ không đầy đủ; nghĩa là, nếu không qua được test thì là code sai, nhưng nếu qua được test thì chưa chắc đã đúng hoàn toàn.
#
# Trong khi làm bài, bạn có thể cho in ra màn hình, tạo thêm các cell để test. Nhưng khi nộp bài thì bạn xóa các cell mà bạn tự tạo, xóa hoặc comment các câu lệnh in ra màn hình. Bạn lưu ý <font color=red>không được tự tiện xóa các cell hay sửa code của Thầy</font> (trừ những chỗ được phép sửa như đã nói ở trên).
#
# Bạn cố gắng giữ cho code rõ ràng, ngăn nắp: đặt tên biến gợi ý, comment ở những chỗ cần comment, giữ cho một dòng code không quá dài (vì nếu không thì người đọc sẽ phải mất công scroll, bạn có thể dùng qui tắc: một dòng code chỉ nên có tối đa là 79 ký tự).
#
# Trong khi làm bài, thường xuyên `Ctrl + S` để lưu lại bài làm của bạn, tránh mất mát thông tin.
#
#
# *Nên nhớ mục tiêu chính ở đây là <font color=green>học, học một cách chân thật</font>. Bạn có thể thảo luận ý tưởng với bạn khác, nhưng <font color=green>code và bài làm phải là của bạn, dựa trên sự hiểu thật sự của bạn</font>. <font color=red>Nếu vi phạm thì sẽ bị 0 điểm cho toàn bộ môn học.</font>*
#
# **Cách nộp bài**
#
# Khi chấm bài, đầu tiên mình sẽ chọn `Kernel` - `Restart & Run All` để restart và chạy tất cả các cell trong notebook của bạn; do đó, trước khi nộp bài, bạn nên chạy thử `Kernel` - `Restart & Run All` để đảm bảo mọi chuyện diễn ra đúng như mong đợi.
#
# Sau đó, bạn tạo thư mục nộp bài theo cấu trúc sau:
# - Thư mục `MSSV` (vd, nếu bạn có MSSV là 1234567 thì bạn đặt tên thư mục là `1234567`)
#     - File `HW01.ipynb` (không cần nộp các file khác)
#
# Cuối cùng, bạn nén thư mục `MSSV` này lại và nộp ở link trên moodle. <font color=red>Bạn lưu ý tuân thủ chính xác qui định nộp bài.</font>

# %% [markdown]
# ---

# %% [markdown]
# ## Môi trường code

# %% [markdown]
# Ta thống nhất trong môn này:
# - Code trên môi trường Linux (bạn đã setup ở HW0)
# - Dùng Jupyter Notebook hoặc Jupyter Lab để code file .ipynb. Lưu ý: bạn <font color=red>không dùng Google Colab</font>, vì Google Colab có thể xóa một số thông tin meta mà chương trình hỗ trợ chấm bài của mình đã tạo trong file bài tập
# - Dùng phiên bản các package như trong file "min_ds-env.yml" (bạn xem trong HW0 cách dùng Conda để tạo môi trường code từ file .yml và cách kích hoạt môi trường này sau khi đã tạo)

# %%
import sys
sys.executable
# Out:
# 'D:\\miniconda3\\envs\\min_ds-env\\python.exe'

# %% [markdown]
# Nếu không có vấn đề gì thì file chạy python sẽ là file của môi trường code "min_ds-env".
#
# Trong bài này, ngoài Git & Jupyter Notebook/Lab thì bạn chỉ dùng Python, không dùng các thư viện khác như Numpy, Pandas, ... Trong Python, khi đọc/ghi file csv thì bạn cũng không được dùng các thư viện hỗ trợ như thư viện `csv`.

# %% [markdown]
# ---

# %% [markdown]
# ## Import các thư viện cần thiết

# %%
import datetime
# YOUR CODE HERE (OPTION)
import os

# %% [markdown]
# ---

# %% [markdown]
# ## Thu thập dữ liệu (3.5đ)

# %% [markdown]
# Trong bài tập này, bạn sẽ lấy dữ liệu log của [thùng chứa nbdime](https://github.com/namlnhut/nbdime). Nbdime là công cụ giúp Git có thể diff và merge file Notebook một cách phù hợp (thay vì chỉ coi như là một file text thông thường). Link mình cung cấp không phải là link đến thùng chứa gốc của nbdime mà là thùng chứa mình "fork" (đại khái là tạo ra một bản copy) từ thùng chứa gốc. Lý do: mình muốn cố định lại dữ liệu log để có thể cung cấp các bộ test để bạn phần nào biết là đã code đúng hay chưa (còn nếu dùng thùng chứa gốc thì dữ liệu log có thể sẽ thay đổi trong vài ngày tới, các bộ test lúc đó có thể sẽ không còn đúng nữa).
#
# Để có thể lấy dữ liệu log thì việc đầu tiên bạn cần làm ở cell bên dưới là:
#
# - Dùng câu lệnh Git để clone thùng chứa về; bạn clone vào một thư mục cùng cấp với file notebook này. <font color=gray>Gợi ý: trong Jupyter Notebook, ở code cell, bạn có thể thực hiện một câu lệnh Linux (bao gồm câu lệnh Git) bằng cách thêm dấu ! ở đầu.</font>
# - Sau đó, để xem thử thư mục vừa clone có nặng không, bạn tính dung lượng tổng cộng của thư mục này và lưu vào biến `repo_size` (`repo_size` là một con số, đơn vị là MB); ta thống nhất: (i) dùng cờ `--apparent-size` khi dùng câu lệnh `du`, (ii) code chỉ cần chạy đúng với thùng chứa cụ thể này. <font color=gray>Gợi ý: trong Jupyter Notebook, bạn có thể gán kết quả của câu lệnh Linux vào biến Python.</font> \
# @ Các bạn dùng Mac: trong Mac thì mình nghe nói là câu lệnh `du` không có cờ `--apparent-size` (do câu lệnh `du` của Mac là bản BSD, còn của Linux là bản GNU); bạn có thể xem thử cách cài câu lệnh `du` bản GNU ở [video này](https://youtu.be/VGgTmxXp7xQ?t=894) (trong video là nói về câu lệnh `grep` nhưng mình nghĩ cũng sẽ tương tự với câu lệnh `du`).

# %%
# YOUR CODE HERE
repo_name = 'nbdime'
repo_url = 'https://github.com/namlnhut/nbdime'
    
# !git clone {repo_url}

du_output = !du -s --apparent-size {repo_name}
kb_size_str = du_output[0].split('\t')[0]
kb_size_int = int(kb_size_str)

repo_size = kb_size_int/1024.0

repo_size
# Out:
# fatal: destination path 'nbdime' already exists and is not an empty directory.
# 21.0078125

# %% [markdown]
# Sau khi đã clone thùng chứa về, việc kế tiếp của bạn là dùng các câu lệnh Linux (trong đó có các câu lệnh Git) và Python để lấy dữ liệu log rồi lưu xuống file "log.tsv" (định dạng tsv tương tự như csv nhưng các giá trị được cách nhau bởi tab). Để dễ hình dung, bạn có thể dùng Jupyter Lab để mở xem file kết quả đúng "correct_log.tsv" mà mình cung cấp. Như bạn có thể thấy, mỗi dòng ứng với một commit (không tính dòng đầu - dòng chứa các tên cột) và gồm các thông tin:
# - "Id" là id (hash) dạng viết gọn của commit
# - "ParentIds" là id dạng viết gọn của (các) commit cha
# - "AuthorName" là tên của tác giả
# - "AuthorEmail" là email của tác giả
# - "AuthorDate" là ngày tác giả thực hiện commit, ngày được format theo chuẩn RFC2822 (xem phần gợi ý ở bên dưới để biết cách lấy ngày theo format này)
# - "Subject" là tựa đề của message (message tương tự như email, ngoài phần "subject" thì có thể có thêm phần "body"; ở đây ta chỉ lấy phần "subject")
# - "ChangedFiles": các file bị thay đổi, nếu có nhiều file thì các file được phân tách bởi dấu phẩy
#
# Tại sao mình dùng định dạng tsv thay vì csv? Vì dấu phẩy nhiều khả năng là sẽ có trong phần "subject" của message. Tab ít khả năng sẽ có hơn, nhưng nếu có thì bạn hãy thay bằng bốn khoảng trắng.
#
# <font color=gray>Gợi ý cho phần này:</font>
# - <font color=gray>Bạn có thể xem thêm về câu lệnh `git log` [ở đây](https://git-scm.com/book/en/v2/Git-Basics-Viewing-the-Commit-History)</font>
# - <font color=gray>Khi ở Notebook, bạn thử `cd` đến thư mục clone rồi `pwd` xem? Kết quả như vậy là vì khi thực hiện một dòng lệnh Linux ở Notebook thì Notebook sẽ tạo ra một terminal tạm thời để thực thi dòng lệnh đó trong phút chốc. Như vậy, câu lệnh `cd` vẫn là có `cd` đến thư mục clone nhưng là ở terminal tạm thời; khi câu lệnh `cd` chạy xong thì terminal tạm thời này sẽ được đóng và ta vẫn ở thư mục mà hiện chứa file Notebook. Để có thể `cd` rồi `pwd` thì một cách là ghi 2 câu lệnh này trên một dòng và cách nhau bởi `&&`; lúc này thì cả 2 câu lệnh sẽ được thực thi trên cùng một terminal</font>

# %%
# YOUR CODE HERE

output_name = 'log.tsv'

# !git -C nbdime log --pretty=format:"%h|%p|%an|%ae|%aD|%s" --name-only > raw_log.txt

log_entries = []
entry = {}
changed_files = []

with open("raw_log.txt", "r", encoding="utf-8-sig") as f:
    lines = f.read().splitlines()

for line in lines:
    if "|" in line:
        if entry:
            entry["ChangedFiles"] = ",".join(changed_files)
            log_entries.append(entry)
            entry = {}
            changed_files = []
        parts = line.split("|", 5)
        entry = {
            "Id": parts[0],
            "ParentIds": parts[1],
            "AuthorName": parts[2],
            "AuthorEmail": parts[3],
            "AuthorDate": parts[4],
            "Subject": parts[5].replace("\t", "    "),  # thay tab bằng 4 space
        }
    elif line.strip():
        changed_files.append(line.strip())

# lưu commit cuối
if entry:
    entry["ChangedFiles"] = ",".join(changed_files)
    log_entries.append(entry)

# Ghi ra file log.tsv ở cùng thư mục với notebook
with open(output_name, "w", encoding="utf-8", newline="\n") as f:
    f.write("Id\tParentIds\tAuthorName\tAuthorEmail\tAuthorDate\tSubject\tChangedFiles\n")
    for e in log_entries:
        f.write(
            f"{e['Id']}\t{e['ParentIds']}\t{e['AuthorName']}\t"
            f"{e['AuthorEmail']}\t{e['AuthorDate']}\t{e['Subject']}\t{e['ChangedFiles']}\n"
        )

if os.path.exists("raw_log.txt"):
    os.remove("raw_log.txt")

# %%
# TEST
file = open('log.tsv', 'r')
log = file.read()
file.close()
file = open('correct_log.tsv', 'r')
correct_log = file.read()
file.close()
assert log == correct_log

# %% [markdown]
# ---

# %% [markdown]
# ## Khám phá dữ liệu

# %% [markdown]
# ### Dữ liệu có bao nhiêu dòng và bao nhiêu cột? (0.5đ)

# %% [markdown]
# Đầu tiên, bạn sẽ đọc dữ liệu từ file "log.tsv" (nếu phần thu thập dữ liệu bạn làm chưa đúng thì bạn có thể đọc từ file "correct_log.tsv" mà mình đã cung cấp). Bạn lưu kết quả đọc được vào biến `cols`. Biến `cols` là một dictionary, trong đó mỗi phần tử ứng với một cột, key là chuỗi ứng với tên cột, value là list chứa các giá trị của cột (mỗi giá trị bạn cứ tạm để kiểu dữ liệu là chuỗi).
#
# Kế tiếp, từ biến `cols`, bạn sẽ tính số dòng và số cột, rồi lần lượt lưu vào hai biến là `num_rows` và `num_cols`.

# %%
# YOUR CODE HERE
file_name = 'log.tsv'

cols = {}

with open(file_name, "r", encoding="utf-8-sig") as f:
    lines = f.read().splitlines()

header_columns = lines[0].split("\t")

for column_name in header_columns:
    cols[column_name] = []
    
for line in lines[1:]:
    values = line.split("\t")
    for i in range(len(header_columns)):
        column_name = header_columns[i]
        value = values[i]
        cols[column_name].append(value)

# Tính số dòng và số cột
num_rows = len(cols[header_columns[0]])
num_cols = len(header_columns)

# %%
# TEST
assert num_rows == 2149
assert num_cols == 7
assert set(cols.keys()) == set(['Id', 'ParentIds', 'AuthorName', 
                                'AuthorEmail', 'AuthorDate', 'Subject', 
                                'ChangedFiles'])
id_col_len = len(cols['Id'])
for col_name in cols:
    assert len(cols[col_name]) == id_col_len

# %% [markdown]
# ### Mỗi dòng có ý nghĩa gì? Có vấn đề các dòng có ý nghĩa khác nhau không?

# %% [markdown]
# Mỗi dòng ứng với một commit. Có vẻ không có dòng nào "lạc loài" (nghĩa là không có vấn đề các dòng có ý nghĩa khác nhau).

# %% [markdown]
# ### Dữ liệu có các dòng bị lặp không? (0.25đ)

# %% [markdown]
# Có lẽ là không có. Để chắc ăn thì một cách là ta có thể check cột "Id"; nếu cột "Id" không có giá trị bị lặp thì có thể kết luận là không có dòng bị lặp. Bạn sẽ làm vụ này và lưu kết quả check vào biến `duplicated_id`; biến này bằng True nếu cột "Id" có giá trị lặp và bằng False nếu ngược lại.

# %%
# YOUR CODE HERE
ids = cols['Id']

if len(ids) != len(set(ids)):
    duplicated_id = True
else:
    duplicated_id = False

# %%
# TEST
assert duplicated_id == False

# %% [markdown]
# ### Mỗi cột có ý nghĩa gì?

# %% [markdown]
# Vụ này mình đã nói lúc thu thập dữ liệu. Ở đây, mình ghi lại một lần nữa:
#
# - "Id" là id (hash) dạng viết gọn của commit
# - "ParentIds" là id dạng viết gọn của (các) commit cha
# - "AuthorName" là tên của tác giả
# - "AuthorEmail" là email của tác giả
# - "AuthorDate" là ngày tác giả thực hiện commit
# - "Subject" là tựa đề của message (message tương tự như email, ngoài phần "subject" thì có thể có thêm phần "body"; ở đây ta chỉ lấy phần "subject")
# - "ChangedFiles": các file bị thay đổi, nếu có nhiều file thì các file được phân tách bởi dấu phẩy

# %% [markdown]
# ### Mỗi cột hiện đang có kiểu dữ liệu gì? Có cột nào có kiểu dữ liệu chưa phù hợp để có thể xử lý tiếp không?

# %% [markdown]
# - Các cột "Id", "ParentIds", "AuthorName", "AuthorEmail", "Subject": kiểu dữ liệu dạng chuỗi là đúng rồi
# - Cột "ChangedFiles": hmm ... có lẽ tạm thời ta vẫn để dạng chuỗi, có gì cần thì ta sẽ xử lý sau
# - Cột "AuthorDate": cần chuyển từ kiểu dữ liệu dạng chuỗi sang datetime; để có thể tiếp tục khám phá tiếp thì ngay sau đây bạn sẽ tiền xử lý vụ này luôn

# %% [markdown]
# ---

# %% [markdown]
# ## Tiền xử lý (0.5đ)

# %% [markdown]
# Ở đây, bạn sẽ chuyển cột "AuthorDate" từ dạng chuỗi sang datetime. <font color=gray>Gợi ý: bạn xem [document](https://docs.python.org/3/library/datetime.html#strftime-and-strptime-format-codes) để biết cách truyền format phù hợp cho hàm `strptime`.</font>

# %%
# YOUR CODE HERE
authorDate_str = cols['AuthorDate']

authorDate_dt = []
for date_str in authorDate_str:
    dt = datetime.datetime.strptime(date_str, "%a, %d %b %Y %H:%M:%S %z")
    authorDate_dt.append(dt)

cols["AuthorDate"] = authorDate_dt

# %%
# TEST
assert type(cols['AuthorDate'][0]) == datetime.datetime
assert cols['AuthorDate'][0] == datetime.datetime(2025, 10, 9, 11, 32, 46, 
            tzinfo=datetime.timezone(datetime.timedelta(seconds=7200)))

# %% [markdown]
# ---

# %% [markdown]
# ## Khám phá dữ liệu (tiếp tục)

# %% [markdown]
# ### Với mỗi cột có kiểu dữ liệu dạng số (numeric) và dạng datetime, các giá trị được phân bố như thế nào? (0.5đ)

# %% [markdown]
# Ở đây thì không có cột dạng số, chỉ có một cột dạng datetime là cột "AuthorDate".
#
# Đầu tiên, bạn tính tỉ lệ % các giá trị thiếu của cột "AuthorDate". <font color=gray>Gợi ý: không cần code, có thể lập luận dựa vào kết quả khi chuyển cột "AuthorDate" từ dạng chuỗi sang datetime ở bên trên.</font>

# %% [markdown]
# YOUR ANSWER HERE
#
# **Đáp án**: Tỉ lệ % các giá trị thiếu của cột "AuthorDate" là <font color=blue>0%</font>.
#
# **Lý do**: Commit nào cũng được `git log` cung cấp ngày giờ (`AuthorDate`) nên theo logic không thể có commit nào thiếu `AuthorDate`. Ngoài ra, khi chuyển cột `AuthorDate` từ chuỗi sang `datetime`, toàn bộ giá trị trong cột đều được parse thành công vì nếu có giá trị thiếu thì `strptime` đã báo lỗi ngay.

# %% [markdown]
# Tiếp theo, bạn tính min và max của cột "AuthorDate", rồi lần lượt lưu vào hai biến `author_date_min` và `author_date_max`.

# %%
# YOUR CODE HERE
author_date_min = min(cols['AuthorDate'])
author_date_max = max(cols['AuthorDate'])

# %%
# TEST
assert author_date_min == datetime.datetime(2015, 11, 9, 13, 13, 28, 
            tzinfo=datetime.timezone(datetime.timedelta(seconds=3600)))
assert author_date_max == datetime.datetime(2025, 10, 9, 11, 32, 46, 
            tzinfo=datetime.timezone(datetime.timedelta(seconds=7200)))

# %% [markdown]
# Hmm ... Min và max của cột "AuthorDate" không có gì bất thường.

# %% [markdown]
# ### Với mỗi cột có kiểu dữ liệu dạng phân loại (categorical), các giá trị được phân bố như thế nào? (1.75đ)

# %% [markdown]
# Các cột dạng phân loại là các cột mà không phải là cột "AuthorDate". Bạn sẽ lưu thông tin của các cột này vào biến `cate_col_profiles`. Biến này là một dictionary, trong đó mỗi phần tử ứng với một cột dạng phân loại, key là tên cột, value là list gồm: tỉ lệ % giá trị thiếu, số lượng các giá trị khác nhau (không tính giá trị thiếu), set chứa các giá trị khác nhau (không bao gồm giá trị thiếu).

# %%
# YOUR CODE HERE

cate_col_profiles = {}

for col_name in cols:
    if col_name == "AuthorDate":
        continue
    
    column_values = cols[col_name]
    total_values  = len(column_values)
    
    # Giá trị thiếu coi là chuỗi rỗng
    missing_count = 0
    for value in column_values:
        if value == "" or value is None:
            missing_count += 1
    missing_rate = (missing_count / total_values) * 100
    
    # Các giá trị khác nhau (loại bỏ thiếu)
    unique_values = set()
    for value in column_values:
        if value != "" and value is not None:
            unique_values.add(value)
    num_unique = len(unique_values)
    
    cate_col_profiles[col_name] = [
        missing_rate,
        num_unique,
        unique_values
    ]

# %%
# TEST
assert set(cate_col_profiles.keys()) == {'AuthorEmail', 'AuthorName', 
                                         'ChangedFiles', 'Id', 
                                         'ParentIds', 'Subject'}
for col_name, col_profile in cate_col_profiles.items():
    assert len(col_profile) == 3
    assert len(col_profile[2]) == col_profile[1]
assert round(cate_col_profiles['ParentIds'][0], 3) == 0.047
assert round(cate_col_profiles['ChangedFiles'][0], 3) == 15.914
assert cate_col_profiles['ParentIds'][1] == 2029
assert cate_col_profiles['ChangedFiles'][1] == 934

# %%
# TEST (BY EYES)
print(f"{'ColName':12} {'Miss(%)':7} {'NumDifVals':10} {'SomeVals'}")
for col_name, col_profile in cate_col_profiles.items():
    print(f'{col_name:12} {col_profile[0]:<7.3f} {col_profile[1]:<10} {col_profile[2].__repr__()[:34]+"...":<}')
# Out:
# ColName      Miss(%) NumDifVals SomeVals
# Id           0.000   2149       {'ef3f17a', 'ce95388', '69fd198', ...
# ParentIds    0.047   2029       {'ef3f17a', 'ce95388', '69fd198', ...
# AuthorName   0.000   55         {'Chih-Hsuan Yen', 'Tarek Allam', ...
# AuthorEmail  0.000   58         {'krassowski.michal@gmail.com', 't...
# Subject      0.000   2058       {'Enable inline-source strategy an...
# ChangedFiles 15.914  934        {'nbdime/gitdiffdriver.py,nbdime/g...

# %% [markdown]
# Bạn quan sát kết quả in ra ở trên (tạm thời chưa để ý đến cột "Miss(%)") và cho biết có gì bất thường không? Hay mọi thứ đều bình thường? Cho mình biết tại sao bạn lại kết luận như vậy.

# %% [markdown]
# **Đáp án**: Mọi thứ đều <font color=blue>bình thường</font>.
#
# **Lý do**: Các con số hoàn toàn hợp lý với đặc thù dữ liệu Git:
# - Id = số commit.
# - ParentIds < Id vì nhiều commit có cùng parent.
# - AuthorName << Id do có nhiều commit nhưng ít người contribute.
# - AuthorEmail > AuthorName do một tác giả có thể dùng nhiều email khác nhau.
# - Subject gần bằng số commit vì nhiều commit có subject trùng nhau.
# - ChangedFiles ít hơn số commit vì nhiều commit có thể thay đổi cùng một file hoặc cùng một nhóm file.

# %% [markdown]
# Kế tiếp, bạn hãy cho in ra các dòng mà có giá trị thiếu (in sao là tùy bạn, miễn là dễ nhìn). Sau đó, bạn hãy quan sát các dòng này để xem tại sao lại bị thiếu (trong trường hợp, bạn không biết tại sao thì cứ ghi nhận là không biết tại sao).

# %%
# YOUR CODE HERE
num_rows = len(cols["Id"])

for i in range(num_rows):
    missing_cols = []
    for col_name in cols:
        # Bỏ qua các cột không bị thiếu
        if (col_name == "AuthorDate" or col_name == "Id" or col_name == "AuthorName" 
            or col_name == "AuthorEmail" or col_name == "Subject"):
            continue
        value = cols[col_name][i]
        if value == "" or value is None:
            missing_cols.append(col_name)
    
    if missing_cols:
        print(f"- Commit Id: {cols['Id'][i]}")
        for col in missing_cols:
            print(f"    {col} = (thiếu)")
        print()
# Out:
# - Commit Id: 606b6fd
#     ChangedFiles = (thiếu)
#
# - Commit Id: ecf8996
#     ChangedFiles = (thiếu)
#
# - Commit Id: 3dcdce3
#     ChangedFiles = (thiếu)
#
# - Commit Id: 2f54b80
#     ChangedFiles = (thiếu)
#
# - Commit Id: e56e9fa
#     ChangedFiles = (thiếu)
#
# - Commit Id: c1ea9b9
#     ChangedFiles = (thiếu)
#
# - Commit Id: 3c064bd
#     ChangedFiles = (thiếu)
#
# - Commit Id: e6d2e28
#     ChangedFiles = (thiếu)
#
# - Commit Id: 2db03bc
#     ChangedFiles = (thiếu)
#
# - Commit Id: ac5eb35
#     ChangedFiles = (thiếu)
#
# - Commit Id: da240a2
#     ChangedFiles = (thiếu)
#
# - Commit Id: 43168fc
#     ChangedFiles = (thiếu)
#
# - Commit Id: b1804b1
#     ChangedFiles = (thiếu)
#
# - Commit Id: 691b9c8
#     ChangedFiles = (thiếu)
#
# - Commit Id: 9fbfd46
#     ChangedFiles = (thiếu)
#
# - Commit Id: 50c9347
#     ChangedFiles = (thiếu)
#
# - Commit Id: 2da614b
#     ChangedFiles = (thiếu)
#
# - Commit Id: 0d57918
#     ChangedFiles = (thiếu)
#
# - Commit Id: fe11ad5
#     ChangedFiles = (thiếu)
#
# - Commit Id: f503763
#     ChangedFiles = (thiếu)
#
# - Commit Id: 4bc7ae2
#     ChangedFiles = (thiếu)
#
# - Commit Id: ecded88
#     ChangedFiles = (thiếu)
#
# - Commit Id: 2db0b44
#     ChangedFiles = (thiếu)
#
# - Commit Id: fa4e2a3
#     ChangedFiles = (thiếu)
#
# - Commit Id: bbf621e
#     ChangedFiles = (thiếu)
#
# - Commit Id: fc31fbb
#     ChangedFiles = (thiếu)
#
# - Commit Id: 17d103c
#     ChangedFiles = (thiếu)
#
# - Commit Id: e44a5cc
#     ChangedFiles = (thiếu)
#
# - Commit Id: f16d448
#     ChangedFiles = (thiếu)
#
# - Commit Id: 5f05329
#     ChangedFiles = (thiếu)
#
# - Commit Id: 559d785
#     ChangedFiles = (thiếu)
#
# - Commit Id: 9df6aea
#     ChangedFiles = (thiếu)
#
# - Commit Id: 524aac2
#     ChangedFiles = (thiếu)
#
# - Commit Id: ab8e60d
#     ChangedFiles = (thiếu)
#
# - Commit Id: f1e18ff
#     ChangedFiles = (thiếu)
#
# - Commit Id: 52f7990
#     ChangedFiles = (thiếu)
#
# - Commit Id: 8ce708c
#     ChangedFiles = (thiếu)
#
# - Commit Id: 075f502
#     ChangedFiles = (thiếu)
#
# - Commit Id: 4291b8c
#     ChangedFiles = (thiếu)
#
# - Commit Id: ab9f1bc
#     ChangedFiles = (thiếu)
#
# - Commit Id: fe2911a
#     ChangedFiles = (thiếu)
#
# - Commit Id: a0726e5
#     ChangedFiles = (thiếu)
#
# - Commit Id: 75363a0
#     ChangedFiles = (thiếu)
#
# - Commit Id: f6beb60
#     ChangedFiles = (thiếu)
#
# - Commit Id: 77cac58
#     ChangedFiles = (thiếu)
#
# - Commit Id: b707946
#     ChangedFiles = (thiếu)
#
# - Commit Id: 141b2dc
#     ChangedFiles = (thiếu)
#
# - Commit Id: f259cae
#     ChangedFiles = (thiếu)
#
# - Commit Id: eaf9c06
#     ChangedFiles = (thiếu)
#
# - Commit Id: d330173
#     ChangedFiles = (thiếu)
#
# - Commit Id: 133c4bf
#     ChangedFiles = (thiếu)
#
# - Commit Id: a9435d5
#     ChangedFiles = (thiếu)
#
# - Commit Id: a506b66
#     ChangedFiles = (thiếu)
#
# - Commit Id: d067442
#     ChangedFiles = (thiếu)
#
# - Commit Id: d9cbd7b
#     ChangedFiles = (thiếu)
#
# - Commit Id: 425c46d
#     ChangedFiles = (thiếu)
#
# - Commit Id: 6259cd0
#     ChangedFiles = (thiếu)
#
# - Commit Id: 137182a
#     ChangedFiles = (thiếu)
#
# - Commit Id: a9faba1
#     ChangedFiles = (thiếu)
#
# - Commit Id: cdadb44
#     ChangedFiles = (thiếu)
#
# - Commit Id: 300067c
#     ChangedFiles = (thiếu)
#
# - Commit Id: 0590d1b
#     ChangedFiles = (thiếu)
#
# - Commit Id: fabbeb7
#     ChangedFiles = (thiếu)
#
# - Commit Id: ba18b56
#     ChangedFiles = (thiếu)
#
# - Commit Id: 8940d58
#     ChangedFiles = (thiếu)
#
# - Commit Id: 0910bcd
#     ChangedFiles = (thiếu)
#
# - Commit Id: b8c7829
#     ChangedFiles = (thiếu)
#
# - Commit Id: 91ac9bf
#     ChangedFiles = (thiếu)
#
# - Commit Id: 31b716e
#     ChangedFiles = (thiếu)
#
# - Commit Id: 07714c0
#     ChangedFiles = (thiếu)
#
# - Commit Id: 435ce3b
#     ChangedFiles = (thiếu)
#
# - Commit Id: c24fc22
#     ChangedFiles = (thiếu)
#
# - Commit Id: 5a92521
#     ChangedFiles = (thiếu)
#
# - Commit Id: ed222a2
#     ChangedFiles = (thiếu)
#
# - Commit Id: abdde8f
#     ChangedFiles = (thiếu)
#
# - Commit Id: d3a0962
#     ChangedFiles = (thiếu)
#
# - Commit Id: 959ce75
#     ChangedFiles = (thiếu)
#
# - Commit Id: 98c3af9
#     ChangedFiles = (thiếu)
#
# - Commit Id: 98bf4dc
#     ChangedFiles = (thiếu)
#
# - Commit Id: c968e6f
#     ChangedFiles = (thiếu)
#
# - Commit Id: eef0e50
#     ChangedFiles = (thiếu)
#
# - Commit Id: 559bae6
#     ChangedFiles = (thiếu)
#
# - Commit Id: fb6484a
#     ChangedFiles = (thiếu)
#
# - Commit Id: 3fc3e9a
#     ChangedFiles = (thiếu)
#
# - Commit Id: a93b42c
#     ChangedFiles = (thiếu)
#
# - Commit Id: 9cf252c
#     ChangedFiles = (thiếu)
#
# - Commit Id: fc1af0c
#     ChangedFiles = (thiếu)
#
# - Commit Id: 220bc1f
#     ChangedFiles = (thiếu)
#
# - Commit Id: cf45e47
#     ChangedFiles = (thiếu)
#
# - Commit Id: 7748bd5
#     ChangedFiles = (thiếu)
#
# - Commit Id: f0d66a6
#     ChangedFiles = (thiếu)
#
# - Commit Id: 0e47f41
#     ChangedFiles = (thiếu)
#
# - Commit Id: 32df48a
#     ChangedFiles = (thiếu)
#
# - Commit Id: f50d8e5
#     ChangedFiles = (thiếu)
#
# - Commit Id: bf8da35
#     ChangedFiles = (thiếu)
#
# - Commit Id: c30847b
#     ChangedFiles = (thiếu)
#
# - Commit Id: ef9d708
#     ChangedFiles = (thiếu)
#
# - Commit Id: 1bb9458
#     ChangedFiles = (thiếu)
#
# - Commit Id: 25878a5
#     ChangedFiles = (thiếu)
#
# - Commit Id: 0234912
#     ChangedFiles = (thiếu)
#
# - Commit Id: e510209
#     ChangedFiles = (thiếu)
#
# - Commit Id: 1b332c8
#     ChangedFiles = (thiếu)
#
# - Commit Id: ffaaf75
#     ChangedFiles = (thiếu)
#
# - Commit Id: 28a436b
#     ChangedFiles = (thiếu)
#
# - Commit Id: 52e68c8
#     ChangedFiles = (thiếu)
#
# - Commit Id: 09ce7af
#     ChangedFiles = (thiếu)
#
# - Commit Id: bd9873c
#     ChangedFiles = (thiếu)
#
# - Commit Id: f330467
#     ChangedFiles = (thiếu)
#
# - Commit Id: 2656120
#     ChangedFiles = (thiếu)
#
# - Commit Id: 55d56ee
#     ChangedFiles = (thiếu)
#
# - Commit Id: d59a446
#     ChangedFiles = (thiếu)
#
# - Commit Id: e03c861
#     ChangedFiles = (thiếu)
#
# - Commit Id: 7914988
#     ChangedFiles = (thiếu)
#
# - Commit Id: 0a60cdc
#     ChangedFiles = (thiếu)
#
# - Commit Id: e4b9dc6
#     ChangedFiles = (thiếu)
#
# - Commit Id: 670e8a0
#     ChangedFiles = (thiếu)
#
# - Commit Id: 77398e0
#     ChangedFiles = (thiếu)
#
# - Commit Id: f16ecac
#     ChangedFiles = (thiếu)
#
# - Commit Id: 350f5ca
#     ChangedFiles = (thiếu)
#
# - Commit Id: 8d6421d
#     ChangedFiles = (thiếu)
#
# - Commit Id: ac7358f
#     ChangedFiles = (thiếu)
#
# - Commit Id: 7c4b998
#     ChangedFiles = (thiếu)
#
# - Commit Id: c21fd7f
#     ChangedFiles = (thiếu)
#
# - Commit Id: eac0417
#     ChangedFiles = (thiếu)
#
# - Commit Id: e019d4c
#     ChangedFiles = (thiếu)
#
# - Commit Id: 05c5047
#     ChangedFiles = (thiếu)
#
# - Commit Id: f0a36a1
#     ChangedFiles = (thiếu)
#
# - Commit Id: 344a450
#     ChangedFiles = (thiếu)
#
# - Commit Id: 4022e8c
#     ChangedFiles = (thiếu)
#
# - Commit Id: f0284ac
#     ChangedFiles = (thiếu)
#
# - Commit Id: 2354345
#     ChangedFiles = (thiếu)
#
# - Commit Id: f884858
#     ChangedFiles = (thiếu)
#
# - Commit Id: dfff8ff
#     ChangedFiles = (thiếu)
#
# - Commit Id: 7240999
#     ChangedFiles = (thiếu)
#
# - Commit Id: d5a3b66
#     ChangedFiles = (thiếu)
#
# - Commit Id: e81d466
#     ChangedFiles = (thiếu)
#
# - Commit Id: ce16aec
#     ChangedFiles = (thiếu)
#
# - Commit Id: c1a95e1
#     ChangedFiles = (thiếu)
#
# - Commit Id: 06784cd
#     ChangedFiles = (thiếu)
#
# - Commit Id: 13d10af
#     ChangedFiles = (thiếu)
#
# - Commit Id: 31233af
#     ChangedFiles = (thiếu)
#
# - Commit Id: a70fc47
#     ChangedFiles = (thiếu)
#
# - Commit Id: 85b9439
#     ChangedFiles = (thiếu)
#
# - Commit Id: fd10644
#     ChangedFiles = (thiếu)
#
# - Commit Id: 7bb9fae
#     ChangedFiles = (thiếu)
#
# - Commit Id: a184e7e
#     ChangedFiles = (thiếu)
#
# - Commit Id: b0327b0
#     ChangedFiles = (thiếu)
#
# - Commit Id: e9ba0e4
#     ChangedFiles = (thiếu)
#
# - Commit Id: cad565e
#     ChangedFiles = (thiếu)
#
# - Commit Id: 4da3738
#     ChangedFiles = (thiếu)
#
# - Commit Id: a489683
#     ChangedFiles = (thiếu)
#
# - Commit Id: cfb7408
#     ChangedFiles = (thiếu)
#
# - Commit Id: bc93659
#     ChangedFiles = (thiếu)
#
# - Commit Id: 40dec01
#     ChangedFiles = (thiếu)
#
# - Commit Id: 6c3e8bb
#     ChangedFiles = (thiếu)
#
# - Commit Id: b384cd4
#     ChangedFiles = (thiếu)
#
# - Commit Id: 36e6b14
#     ChangedFiles = (thiếu)
#
# - Commit Id: edfc38a
#     ChangedFiles = (thiếu)
#
# - Commit Id: 852fd94
#     ChangedFiles = (thiếu)
#
# - Commit Id: 9540d0b
#     ChangedFiles = (thiếu)
#
# - Commit Id: a7496a2
#     ChangedFiles = (thiếu)
#
# - Commit Id: b10078b
#     ChangedFiles = (thiếu)
#
# - Commit Id: 76df65e
#     ChangedFiles = (thiếu)
#
# - Commit Id: 393bd56
#     ChangedFiles = (thiếu)
#
# - Commit Id: 73f5f70
#     ChangedFiles = (thiếu)
#
# - Commit Id: c8f5544
#     ChangedFiles = (thiếu)
#
# - Commit Id: 1dbc671
#     ChangedFiles = (thiếu)
#
# - Commit Id: 2424bc4
#     ChangedFiles = (thiếu)
#
# - Commit Id: 38b1502
#     ChangedFiles = (thiếu)
#
# - Commit Id: 5762bc3
#     ChangedFiles = (thiếu)
#
# - Commit Id: a18f1e8
#     ChangedFiles = (thiếu)
#
# - Commit Id: eedd971
#     ChangedFiles = (thiếu)
#
# - Commit Id: 25909c8
#     ChangedFiles = (thiếu)
#
# - Commit Id: 4530423
#     ChangedFiles = (thiếu)
#
# - Commit Id: 8f000c5
#     ChangedFiles = (thiếu)
#
# - Commit Id: 4bdc258
#     ChangedFiles = (thiếu)
#
# - Commit Id: 83ae911
#     ChangedFiles = (thiếu)
#
# - Commit Id: e64d9f7
#     ChangedFiles = (thiếu)
#
# - Commit Id: 352e8a5
#     ChangedFiles = (thiếu)
#
# - Commit Id: 9e6f400
#     ChangedFiles = (thiếu)
#
# - Commit Id: 9c4f355
#     ChangedFiles = (thiếu)
#
# - Commit Id: 804cea7
#     ChangedFiles = (thiếu)
#
# - Commit Id: 9531aa9
#     ChangedFiles = (thiếu)
#
# - Commit Id: 990fded
#     ChangedFiles = (thiếu)
#
# - Commit Id: 46df21e
#     ChangedFiles = (thiếu)
#
# - Commit Id: 77982f9
#     ChangedFiles = (thiếu)
#
# - Commit Id: 4ae79a8
#     ChangedFiles = (thiếu)
#
# - Commit Id: 6d9aaec
#     ChangedFiles = (thiếu)
#
# - Commit Id: b9c3184
#     ChangedFiles = (thiếu)
#
# - Commit Id: 5c92cfb
#     ChangedFiles = (thiếu)
#
# - Commit Id: 65ced79
#     ChangedFiles = (thiếu)
#
# - Commit Id: 84e6cf3
#     ChangedFiles = (thiếu)
#
# - Commit Id: 823dfd6
#     ChangedFiles = (thiếu)
#
# - Commit Id: b1454bc
#     ChangedFiles = (thiếu)
#
# - Commit Id: 6bdacd4
#     ChangedFiles = (thiếu)
#
# - Commit Id: 900b22e
#     ChangedFiles = (thiếu)
#
# - Commit Id: 3df71d0
#     ChangedFiles = (thiếu)
#
# - Commit Id: 361b2f1
#     ChangedFiles = (thiếu)
#
# - Commit Id: 9bece08
#     ChangedFiles = (thiếu)
#
# - Commit Id: f311624
#     ChangedFiles = (thiếu)
#
# - Commit Id: 5560090
#     ChangedFiles = (thiếu)
#
# - Commit Id: 941a4e1
#     ChangedFiles = (thiếu)
#
# - Commit Id: ad6ebdc
#     ChangedFiles = (thiếu)
#
# - Commit Id: c032666
#     ChangedFiles = (thiếu)
#
# - Commit Id: f384cd1
#     ChangedFiles = (thiếu)
#
# - Commit Id: c9bde54
#     ChangedFiles = (thiếu)
#
# - Commit Id: c1a0588
#     ChangedFiles = (thiếu)
#
# - Commit Id: 874e618
#     ChangedFiles = (thiếu)
#
# - Commit Id: b691ab5
#     ChangedFiles = (thiếu)
#
# - Commit Id: fafea8a
#     ChangedFiles = (thiếu)
#
# - Commit Id: 7e63061
#     ChangedFiles = (thiếu)
#
# - Commit Id: e7f1a48
#     ChangedFiles = (thiếu)
#
# - Commit Id: 9a4f9f8
#     ChangedFiles = (thiếu)
#
# - Commit Id: cd2f57a
#     ChangedFiles = (thiếu)
#
# - Commit Id: 26704cd
#     ChangedFiles = (thiếu)
#
# - Commit Id: 64571fb
#     ChangedFiles = (thiếu)
#
# - Commit Id: 1ca93bf
#     ChangedFiles = (thiếu)
#
# - Commit Id: 0f9e801
#     ChangedFiles = (thiếu)
#
# - Commit Id: 52e7f16
#     ChangedFiles = (thiếu)
#
# - Commit Id: b796d33
#     ChangedFiles = (thiếu)
#
# - Commit Id: bc69972
#     ChangedFiles = (thiếu)
#
# - Commit Id: 0aa75f8
#     ChangedFiles = (thiếu)
#
# - Commit Id: da9b138
#     ChangedFiles = (thiếu)
#
# - Commit Id: c8ff67e
#     ChangedFiles = (thiếu)
#
# - Commit Id: 8247775
#     ChangedFiles = (thiếu)
#
# - Commit Id: a8dc069
#     ChangedFiles = (thiếu)
#
# - Commit Id: 938d0d6
#     ChangedFiles = (thiếu)
#
# - Commit Id: cb2e3e7
#     ChangedFiles = (thiếu)
#
# - Commit Id: a780dfa
#     ChangedFiles = (thiếu)
#
# - Commit Id: 1d49827
#     ChangedFiles = (thiếu)
#
# - Commit Id: 5078eee
#     ChangedFiles = (thiếu)
#
# - Commit Id: c375fe4
#     ChangedFiles = (thiếu)
#
# - Commit Id: 60bc309
#     ChangedFiles = (thiếu)
#
# - Commit Id: 6ae471f
#     ChangedFiles = (thiếu)
#
# - Commit Id: fe4b29a
#     ChangedFiles = (thiếu)
#
# - Commit Id: 44ff95e
#     ChangedFiles = (thiếu)
#
# - Commit Id: 43f8bcc
#     ChangedFiles = (thiếu)
#
# - Commit Id: ff7b295
#     ChangedFiles = (thiếu)
#
# - Commit Id: b0d57d5
#     ChangedFiles = (thiếu)
#
# - Commit Id: 5982dcd
#     ChangedFiles = (thiếu)
#
# - Commit Id: 2e520e7
#     ChangedFiles = (thiếu)
#
# - Commit Id: d188aa0
#     ChangedFiles = (thiếu)
#
# - Commit Id: 0d5a79c
#     ChangedFiles = (thiếu)
#
# - Commit Id: 19d7375
#     ChangedFiles = (thiếu)
#
# - Commit Id: 40979fa
#     ChangedFiles = (thiếu)
#
# - Commit Id: aeeb049
#     ChangedFiles = (thiếu)
#
# - Commit Id: 854f22d
#     ChangedFiles = (thiếu)
#
# - Commit Id: 5ea5cc1
#     ChangedFiles = (thiếu)
#
# - Commit Id: dee5c9a
#     ChangedFiles = (thiếu)
#
# - Commit Id: ac153fc
#     ChangedFiles = (thiếu)
#
# - Commit Id: 7b81637
#     ChangedFiles = (thiếu)
#
# - Commit Id: 6455178
#     ChangedFiles = (thiếu)
#
# - Commit Id: 806239e
#     ChangedFiles = (thiếu)
#
# - Commit Id: b20f4a1
#     ChangedFiles = (thiếu)
#
# - Commit Id: 9e4688d
#     ChangedFiles = (thiếu)
#
# - Commit Id: 773a7ba
#     ChangedFiles = (thiếu)
#
# - Commit Id: 8bcf827
#     ChangedFiles = (thiếu)
#
# - Commit Id: ab3cc94
#     ChangedFiles = (thiếu)
#
# - Commit Id: cb3f3a9
#     ChangedFiles = (thiếu)
#
# - Commit Id: 2b56e31
#     ChangedFiles = (thiếu)
#
# - Commit Id: 213d30e
#     ChangedFiles = (thiếu)
#
# - Commit Id: 6140d23
#     ChangedFiles = (thiếu)
#
# - Commit Id: 3723b53
#     ChangedFiles = (thiếu)
#
# - Commit Id: 0aa5782
#     ChangedFiles = (thiếu)
#
# - Commit Id: 753135a
#     ChangedFiles = (thiếu)
#
# - Commit Id: f8767b7
#     ChangedFiles = (thiếu)
#
# - Commit Id: 2fd4a9e
#     ChangedFiles = (thiếu)
#
# - Commit Id: 48e2c13
#     ChangedFiles = (thiếu)
#
# - Commit Id: c4df69b
#     ChangedFiles = (thiếu)
#
# - Commit Id: 6a04033
#     ChangedFiles = (thiếu)
#
# - Commit Id: 9f43c3d
#     ChangedFiles = (thiếu)
#
# - Commit Id: e2fc76b
#     ChangedFiles = (thiếu)
#
# - Commit Id: a5e1f72
#     ChangedFiles = (thiếu)
#
# - Commit Id: 43eca25
#     ChangedFiles = (thiếu)
#
# - Commit Id: c21cab3
#     ChangedFiles = (thiếu)
#
# - Commit Id: 35b7608
#     ChangedFiles = (thiếu)
#
# - Commit Id: db46402
#     ChangedFiles = (thiếu)
#
# - Commit Id: 8792ab4
#     ChangedFiles = (thiếu)
#
# - Commit Id: e93a97f
#     ChangedFiles = (thiếu)
#
# - Commit Id: e3e5f44
#     ChangedFiles = (thiếu)
#
# - Commit Id: 39f146f
#     ChangedFiles = (thiếu)
#
# - Commit Id: f6884b0
#     ChangedFiles = (thiếu)
#
# - Commit Id: f1a348e
#     ChangedFiles = (thiếu)
#
# - Commit Id: 31e286d
#     ChangedFiles = (thiếu)
#
# - Commit Id: acc356a
#     ChangedFiles = (thiếu)
#
# - Commit Id: 481b2cd
#     ChangedFiles = (thiếu)
#
# - Commit Id: 14ed831
#     ChangedFiles = (thiếu)
#
# - Commit Id: 5a6ba9b
#     ChangedFiles = (thiếu)
#
# - Commit Id: e4af609
#     ChangedFiles = (thiếu)
#
# - Commit Id: 4e03e16
#     ChangedFiles = (thiếu)
#
# - Commit Id: c9ffa9c
#     ChangedFiles = (thiếu)
#
# - Commit Id: 4136c51
#     ChangedFiles = (thiếu)
#
# - Commit Id: da17b37
#     ChangedFiles = (thiếu)
#
# - Commit Id: 8501759
#     ChangedFiles = (thiếu)
#
# - Commit Id: 48e865b
#     ChangedFiles = (thiếu)
#
# - Commit Id: b9eca71
#     ChangedFiles = (thiếu)
#
# - Commit Id: 89974ba
#     ChangedFiles = (thiếu)
#
# - Commit Id: 2bed9bb
#     ChangedFiles = (thiếu)
#
# - Commit Id: 9824304
#     ChangedFiles = (thiếu)
#
# - Commit Id: 88acecf
#     ChangedFiles = (thiếu)
#
# - Commit Id: fe87b7a
#     ChangedFiles = (thiếu)
#
# - Commit Id: ce4583a
#     ChangedFiles = (thiếu)
#
# - Commit Id: b94db84
#     ChangedFiles = (thiếu)
#
# - Commit Id: d24fe80
#     ChangedFiles = (thiếu)
#
# - Commit Id: 4e75c5a
#     ChangedFiles = (thiếu)
#
# - Commit Id: 90ede10
#     ChangedFiles = (thiếu)
#
# - Commit Id: b6b9876
#     ChangedFiles = (thiếu)
#
# - Commit Id: 767c7c2
#     ChangedFiles = (thiếu)
#
# - Commit Id: 84bb398
#     ChangedFiles = (thiếu)
#
# - Commit Id: 37a15fe
#     ChangedFiles = (thiếu)
#
# - Commit Id: b3343f9
#     ChangedFiles = (thiếu)
#
# - Commit Id: e387105
#     ChangedFiles = (thiếu)
#
# - Commit Id: 55adbce
#     ChangedFiles = (thiếu)
#
# - Commit Id: 633fe82
#     ChangedFiles = (thiếu)
#
# - Commit Id: d1952dc
#     ChangedFiles = (thiếu)
#
# - Commit Id: 6691bfc
#     ChangedFiles = (thiếu)
#
# - Commit Id: a8fce37
#     ChangedFiles = (thiếu)
#
# - Commit Id: 0d9469d
#     ChangedFiles = (thiếu)
#
# - Commit Id: 312418e
#     ChangedFiles = (thiếu)
#
# - Commit Id: 5044f27
#     ChangedFiles = (thiếu)
#
# - Commit Id: 015483b
#     ChangedFiles = (thiếu)
#
# - Commit Id: b91fc89
#     ChangedFiles = (thiếu)
#
# - Commit Id: 7fcd5b2
#     ChangedFiles = (thiếu)
#
# - Commit Id: a3504cb
#     ChangedFiles = (thiếu)
#
# - Commit Id: b363220
#     ChangedFiles = (thiếu)
#
# - Commit Id: 614882b
#     ChangedFiles = (thiếu)
#
# - Commit Id: 2e6aba7
#     ChangedFiles = (thiếu)
#
# - Commit Id: cc31347
#     ChangedFiles = (thiếu)
#
# - Commit Id: a0303a4
#     ChangedFiles = (thiếu)
#
# - Commit Id: 912ee20
#     ChangedFiles = (thiếu)
#
# - Commit Id: f173d83
#     ChangedFiles = (thiếu)
#
# - Commit Id: d15e6fd
#     ChangedFiles = (thiếu)
#
# - Commit Id: bc2bbfc
#     ChangedFiles = (thiếu)
#
# - Commit Id: 6660a4a
#     ChangedFiles = (thiếu)
#
# - Commit Id: 72fc51f
#     ChangedFiles = (thiếu)
#
# - Commit Id: fbcb81f
#     ChangedFiles = (thiếu)
#
# - Commit Id: 5af7f14
#     ChangedFiles = (thiếu)
#
# - Commit Id: 24a29c2
#     ChangedFiles = (thiếu)
#
# - Commit Id: c261edd
#     ChangedFiles = (thiếu)
#
# - Commit Id: d20e604
#     ChangedFiles = (thiếu)
#
# - Commit Id: 91318f6
#     ChangedFiles = (thiếu)
#
# - Commit Id: dc6604c
#     ChangedFiles = (thiếu)
#
# - Commit Id: f87fb2e
#     ParentIds = (thiếu)

# %% [markdown]
# Các dòng này bị thiếu vì:
#
# - Với **ChangedFiles**: Đây phần lớn là merge commit. Khi merge, Git chỉ gộp thay đổi từ nhánh này sang nhánh khác, nhiều khi không có thay đổi file trực tiếp trong commit đó => Git log sẽ không liệt kê file nào thay đổi => Cột `ChangedFiles` để trống.
# - Với **ParentIds**: Chỉ một commit bị thiếu vì commit này là `root commit` (commit đầu tiên trong repo). Root commit không có parent (vì nó chính là điểm bắt đầu lịch sử của repo) => Cột `ParentIds` để trống.

# %% [markdown]
# ---

# %% [markdown]
# ## Đưa ra câu hỏi có ý nghĩa cần trả lời

# %% [markdown]
# Sau khi khám phá dữ liệu, ta đã hiểu hơn về dữ liệu. Bây giờ, ta hãy xem thử có câu hỏi nào có ý nghĩa mà có thể được trả lời bằng dữ liệu này không.
#
# Các câu hỏi có thể có là:
# - *Câu hỏi 1: trong năm 2021, ai là người có nhiều commit nhất, ai là người có nhiều commit nhì, ...?* \
# Tìm câu trả lời cho câu hỏi này để làm gì? \
# Hmm ... Chẳng hạn để khen thưởng
# - *Câu hỏi 2: commit nào là commit cuối cùng (xét trên "AuthorDate") đã thay đổi file "nbdime/webapp/templates/difftool.html"?* \
# Tìm câu trả lời cho câu hỏi này để làm gì? \
# Hmm ... Chẳng hạn để đổ tội cho tác giả của commit đó ;-)

# %% [markdown]
# ---

# %% [markdown]
# ## Tiền xử lý (nếu cần) + phân tích dữ liệu để trả lời cho câu hỏi 1 (1đ)

# %% [markdown]
# Nhắc lại câu hỏi 1: *trong năm 2023, ai là người có nhiều commit nhất, ai là người có nhiều commit nhì, ...?*
#
# Bạn sẽ lưu kết quả vào biến `wanted_people`. Biến này là một dictionary, mỗi phần tử ứng với một người mà có commit trong năm 2023, key là tên của người đó, value là số lượng commit của người đó. Dictionary này được sort theo value giảm dần.

# %%
# YOUR CODE HERE
wanted_people = {}

num_rows = len(cols["Id"])
for i in range(num_rows):
    commit_date = cols["AuthorDate"][i]
    if commit_date.year == 2023:
        author = cols["AuthorName"][i]
        if author not in wanted_people:
            wanted_people[author] = 0
        wanted_people[author] += 1

wanted_people = dict(sorted(wanted_people.items(), key=lambda x: x[1], reverse=True))

# %%
# TEST
correct_wanted_people = {'Vidar Tonaas Fauske': 62,
                         'Frédéric Collonval': 31,
                         'Florence Haudin': 18,
                         'github-actions[bot]': 14,
                         'fcollonval': 4,
                         'dependabot[bot]': 4,
                         'HaudinFlorence': 4,
                         'krassowski': 3,
                         'Michał Krassowski': 3,
                         'Chih-Hsuan Yen': 2,
                         'Angus Hollands': 1,
                         'Min RK': 1,
                         'Johan Mabille': 1,
                         'Saiwing Yeung': 1,
                         'Cory Gwin': 1}
assert wanted_people == correct_wanted_people

# %% [markdown]
# ---

# %% [markdown]
# ## Tiền xử lý (nếu cần) + phân tích dữ liệu để trả lời cho câu hỏi 2 (2đ)

# %% [markdown]
# Nhắc lại câu hỏi 2: *commit nào là commit cuối cùng (xét trên "AuthorDate") đã thay đổi file "nbdime/webapp/templates/difftool.html"?*
#
# Ta thống nhất: không xét các commit "merge pull request" vì các commit này không có thông tin về "ChangedFiles".
#
# Bạn lưu kết quả vào biến `wanted_commit`. Biến này là một dictionary, trong đó mỗi phần tử ứng với một thông tin của commit, key là tên cột, value là giá trị tương ứng.

# %%
# YOUR CODE HERE

target_file = 'nbdime/webapp/templates/difftool.html'

wanted_commit = None

for i in range(num_rows):
    subject = cols["Subject"][i]
    changed_files = cols["ChangedFiles"][i]
    
    if subject.startswith("Merge pull request"):
        continue
    
    # Nếu commit có thay đổi file cần tìm
    if target_file in changed_files.split(","):
        commit_date = cols["AuthorDate"][i]
        
        # Cập nhật nếu đây là commit đầu tiên tìm thấy
        # hoặc nếu commit này mới hơn commit đã lưu
        if (wanted_commit is None) or (commit_date > wanted_commit["AuthorDate"]):
            wanted_commit = {
                "Id": cols["Id"][i],
                "ParentIds": cols["ParentIds"][i],
                "AuthorName": cols["AuthorName"][i],
                "AuthorEmail": cols["AuthorEmail"][i],
                "AuthorDate": cols["AuthorDate"][i],
                "Subject": cols["Subject"][i],
                "ChangedFiles": cols["ChangedFiles"][i]
            }

# %%
# TEST
correct_wanted_commit = {'Id': 'd39f45a',
 'ParentIds': '8ebbc6e',
 'AuthorName': 'Frédéric Collonval',
 'AuthorEmail': 'fcollonval@users.noreply.github.com',
 'AuthorDate': datetime.datetime(2023, 10, 20, 23, 20, 31, tzinfo=datetime.timezone(datetime.timedelta(seconds=7200))),
 'Subject': 'Do not collapse editor lines in single editor (#719)',
 'ChangedFiles': 'nbdime/webapp/templates/compare.html,nbdime/webapp/templates/diff.html,nbdime/webapp/templates/difftool.html,nbdime/webapp/templates/merge.html,nbdime/webapp/templates/mergetool.html,packages/nbdime/src/common/mergeview.ts,ui-tests/data/merge_test6/center.ipynb,ui-tests/data/merge_test6/left.ipynb,ui-tests/data/merge_test6/right.ipynb,ui-tests/package-lock.json,ui-tests/tests/nbdime-merge-test6.spec.ts,ui-tests/tests/nbdime-merge-test6.spec.ts-snapshots/merge-test6-take-a-snapshot-at-opening-1-linux.png,ui-tests/tests/nbdime-merge-test6.spec.ts-snapshots/merge-test6-take-a-snapshot-at-opening-1-win32.png'}
assert wanted_commit == correct_wanted_commit
